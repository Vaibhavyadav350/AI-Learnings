# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavyadav350/AI-Learnings/blob/main/Multi_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/Lemonade (1).csv')
df.head()
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0  01/01/2017     Sunday         27.0      2.00      15    0.3     10
# 1  02/01/2017     Monday         28.9      1.33      15    0.3     13
# 2  03/01/2017    Tuesday         34.5      1.33      27    0.3     15
# 3  04/01/2017  Wednesday         44.1      1.05      28    0.3     17
# 4  05/01/2017   Thursday         42.4      1.00      33    0.3     18

# %%
df.shape
# Out:
# (365, 7)

# %%
# Regression with certzin inputs
# Forecasting with respect to Date and Time

# %%
# Relationship between Sales and Temperature,
#  Sales and Rainfall, 
#  Sales and Flyers, 
#  Sales and Price

# %%
# Inferential Statistics
# Correlation test

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
print(df['Temperature'].corr(df['Sales']))
plt.scatter(df['Temperature'],df['Sales'])
plt.xlabel('Temperature')
plt.ylabel('Sales')
plt.show()
# Out:
# 0.9898320849779698

# %%
# Out:
# 0.9898320849779698

# %%
# Correlation (-1 to +1)
# Positive Correlation - Greater than 0
# Negative Correlation - Lesser than 0

# %%
import matplotlib.pyplot as plt
print(df['Rainfall'].corr(df['Sales']))
plt.scatter(df['Rainfall'],df['Sales'])
plt.xlabel('Rainfall')
plt.ylabel('Sales')
plt.show()
# Out:
# -0.909213932410103

# %%
import matplotlib.pyplot as plt
print(df['Flyers'].corr(df['Sales']))
plt.scatter(df['Flyers'],df['Sales'])
plt.xlabel('Flyers')
plt.ylabel('Sales')
plt.show()
# Out:
# 0.8051825759184937

# %%
import matplotlib.pyplot as plt
print(df['Price'].corr(df['Sales']))
plt.scatter(df['Price'],df['Sales'])
plt.xlabel('Price')
plt.ylabel('Sales')
plt.show()
# Out:
# 0.5129076895636254

# %%
df['Price'].value_counts()
# Out:
# 0.3    303
# 0.5     62
# Name: Price, dtype: int64

# %%
# Neglect Price column for now because it is a categorical data

# %%
# Consider 3 inputs ( Temperature, Rainfall and Flyers)

# %%
#x = df[['Temperature','Rainfall','Flyers']]
# or Using iloc command
x = df.iloc[:,2:5].values
y = df.iloc[:,6].values

# %%
# Training Data 
# Testing Data
# 75:25

# %%
# model_selection

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (244, 3)
# (121, 3)

# %%
365*0.33
# Out:
# 120.45

# %%
365*0.67
# Out:
# 244.55

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(x_train, y_train)

# %%
y_pred = reg.predict(x_test)
y_pred
# Out:
# array([32.83547606, 20.90990165, 11.76837935, 21.38974336, 18.85934106,
#        34.43286504, 22.52464924, 27.7659493 , 33.2300578 , 29.28206452,
#         7.88793431, 18.11558774, 22.0422039 , 17.55790146, 30.20588436,
#        23.90993393,  9.49208585, 24.63580391, 20.4272001 , 27.2653956 ,
#        18.12579948, 35.19038738, 24.39962305, 28.43576844, 30.22343568,
#        34.51354946, 32.07420372, 25.40803772, 14.65073725, 15.56737791,
#        14.46747776, 25.39463301, 23.38793962, 17.47721704, 33.01551028,
#        27.12454603, 23.19434029, 15.8309887 , 12.37773252, 22.74321528,
#        28.66578838, 13.53015742, 17.09340406, 25.63691129, 28.42144239,
#        29.22173897, 23.97009908, 20.09953376, 10.01966054, 21.66405942,
#        29.20852697, 12.9276826 , 25.8874505 , 28.29136159, 42.33906334,
#        13.4665754 , 25.84516869, 18.26625243, 11.60928101, 23.80402659,
#        29.36330597, 12.53297275, 24.2973688 , 19.92690261, 26.53293578,
# ...

# %%
y_test
# Out:
# array([33, 21, 12, 22, 20, 35, 23, 27, 33, 29, 10, 19, 23, 18, 30, 25, 10,
#        24, 19, 27, 18, 36, 23, 28, 29, 35, 32, 24, 15, 16, 16, 26, 22, 18,
#        34, 27, 23, 17, 14, 22, 29, 15, 18, 24, 27, 29, 25, 19, 11, 20, 30,
#        14, 25, 27, 42, 13, 27, 17, 13, 23, 30, 13, 24, 21, 28, 24, 29, 28,
#        37, 23, 28, 34, 19, 32, 17, 42, 25, 25, 16, 14, 25, 27, 15, 27, 25,
#        22, 23, 26, 25, 27, 19, 24, 32, 28, 30, 30, 29, 16, 29, 14, 41, 20,
#        18, 25, 28, 39, 29, 19, 35, 20, 26, 31, 36, 12, 29, 24, 30, 17, 24,
#        26, 25])

# %%
# Evaluation

# Loss Function : Least
# Accuracy : Highest

# %%
import numpy as np
mse = np.mean(np.square(np.subtract(y_test,y_pred)))
mse
# Out:
# 0.8641937052436436

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 0.8641937052436436

# %%
# r2 score
# Coefficient of determination

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9824577062575081

# %%
# Things to explore :
# Polynomial Features ( Degree of Freedom )
# Regularization (Advanced) : Rigde, Lasso , ElasticNet

# %%
# Optimizer Algorithm using Gradient Descent ( Deep Learning )
