# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavyadav350/AI-Learnings/blob/main/Classification_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
x = iris.data
y = iris.target

# %%
x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0)

# %%
import tensorflow as tf
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(8,input_shape=(4,), activation='relu'))
model.add(tf.keras.layers.Dense(3,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 8)                 40
#
#  dense_1 (Dense)             (None, 3)                 27
#
# ...
# Total params: 67
# Trainable params: 67
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=200)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5494 - accuracy: 0.7232
# Epoch 2/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5468 - accuracy: 0.7232
# Epoch 3/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5441 - accuracy: 0.7232
# Epoch 4/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5417 - accuracy: 0.7232
# Epoch 5/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5389 - accuracy: 0.7232
# Epoch 6/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5366 - accuracy: 0.7232
# Epoch 7/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5338 - accuracy: 0.7232
# Epoch 8/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5311 - accuracy: 0.7232
# Epoch 9/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5289 - accuracy: 0.7232
# Epoch 10/200
# ...

# %%
import numpy as np
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred,axis=1)
y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 2, 1, 2, 0, 1, 2, 0, 0, 2, 2,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 2, 0, 2, 2, 1, 0, 2])

# %%
y_test
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 1])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.8421052631578947
